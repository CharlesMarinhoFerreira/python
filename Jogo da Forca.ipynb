# %%
#Importando o metodo random
import random 

#Metodo para buscar palavras salvas no arquivo palavras.txt aleatóriamente
def rand_word():
    with open("palavras.txt","rt") as f:
        bank = f.readlines()
    return bank[random.randint(0,len(bank))].strip()
acertos = []
lista = []
lista1 = []
lista2 = []
lista3 = ['''O''','''
O
|''','''
O
|/''','''
 O
\|/''','''
 O
\|/
  \ ''','''
 O
\|/
/ \ ''']

y = 0
w = 0
a = 0
z = 0


palavra = rand_world()
#palavra = input("Entre com a palavra com 6 digitos: ")
print(palavra)

for x in palavra:
    lista2.append(x)
    lista.append("_")
    

print(lista2)
    
while y<6:
    a = 0
    palavra2 = input("Entre com uma letra: ")
    
    while a<len(lista2):
        
        #Verifica a palavra2 está contido na lista2
        if palavra2 not in lista2:
            lista1.append(palavra2)
            print(lista3[z])
            lista
            z += 1
            y += 1
            break;
            
        else:
            if lista2[a]==palavra2:
                lista[a]=palavra2
                acertos.append(palavra2)
        a += 1        
    
    #Verifica se a lista2 é igual a lista
    if (set(lista2) == set(lista)):    
            break;
    
    palavras = ""
    for r in lista:
        palavras += r
        
    print("Palavra: %s" %(palavras))
    print("Letras Erradas: %s" %(lista1))
    #Elimina os caracteres duplicados da lista acertos
    acerto = list(set(acertos))
    print("Letras Certas: %s" %(acerto))
    
if (set(lista2) != set(lista)):
    print("Que pena você perdeu!!!")
else:
    print("Parabéns você acerto a palavra: %s" %(lista))
# Out:
# laranja
# ['l', 'a', 'r', 'a', 'n', 'j', 'a']
# Entre com uma letra: l
# Palavra l______
# Letras Erradas: []
# Letras Certas: ['l']
# Entre com uma letra: a
# Palavra la_a__a
# Letras Erradas: []
# Letras Certas: ['a', 'l']
# Entre com uma letra: n
# Palavra la_an_a
# Letras Erradas: []
# Letras Certas: ['n', 'a', 'l']
# Entre com uma letra: r
# Palavra laran_a
# Letras Erradas: []
# Letras Certas: ['r', 'n', 'a', 'l']
# Entre com uma letra: j
# Parabéns você acerto a palavra: ['l', 'a', 'r', 'a', 'n', 'j', 'a']
